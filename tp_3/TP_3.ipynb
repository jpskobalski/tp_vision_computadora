# %% [markdown]
# # Trabajo Práctico III - Visión por Computadora I
#
# Alumnos:
# - Maximiliano Christener
# - Ronald Uthurralt
# - Luis David Díaz Charris
# - Juan Pablo Skobalski

# %% [markdown]
# ---
# Notas:
# - podemos usar el algoritmo template matching en el punto 3?
# - Image stiching en el primer punto?
# - discutir lo visto en clase 5
# ---
